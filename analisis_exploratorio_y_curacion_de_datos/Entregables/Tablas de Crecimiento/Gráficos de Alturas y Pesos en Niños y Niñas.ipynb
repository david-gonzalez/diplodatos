# %% [markdown]
# #### Análisis Exploratorio y Curación de Datos:

# %% [markdown]
# # Gráficos de Alturas y Pesos en Niños y Niñas

# %%
# Inicialmente cargamos las librerías a utilizar:
import pandas
import numpy
import seaborn
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from pylab import rcParams
rcParams['figure.figsize'] = 18, 10

# %% [markdown]
# Enunciado:
# 1. Descargar dataset #1 y #2 en CSV
#     https://www.cdc.gov/growthcharts/percentile_data_files.htm
# 2. Graficar las curvas correspondientes a cada percentil para niños y niñas

# %% [markdown]
# ---
# ### Resolución del Ejercicio:

# %% [markdown]
# # Importamos los datos

# %%
ds_talla = pandas.read_csv('lenageinf.csv')
ds_peso = pandas.read_csv('wtageinf.csv')

# %% [markdown]
# # Verificamos que no haya problemas de importación

# %%
pandas.set_option('display.max_rows', 100)
pandas.set_option('display.max_columns', 500)

# %% [markdown]
# ### Analizamos las Alturas:

# %%
ds_talla
# Out:
#     Sex  Agemos             L            M            S           P3  \
# 0     1       0   1.267004226  49.98888408  0.053112191   44.9250978
# 1     1     0.5   0.511237696   52.6959753  0.048692684  47.97812373
# 2     1     1.5   -0.45224446  56.62842855   0.04411683  52.19859469
# 3     1     2.5  -0.990594599  59.60895343  0.041795583   55.2632178
# 4     1     3.5  -1.285837689  62.07700027  0.040454126  57.73049293
# 5     1     4.5   -1.43031238   64.2168641  0.039633879  59.82568616
# 6     1     5.5   -1.47657547   66.1253149  0.039123813  61.66383709
# 7     1     6.5  -1.456837849   67.8601799  0.038811994  63.31224239
# 8     1     7.5  -1.391898768  69.45908458  0.038633209   64.8139542
# 9     1     8.5   -1.29571459  70.94803912  0.038546833   66.1983257
# 10    1     9.5  -1.177919048  72.34586111  0.038526262  67.48634824
# 11    1    10.5  -1.045326049   73.6666541  0.038553387  68.69360304
# 12    1    11.5  -0.902800887  74.92129717  0.038615501  69.83200143
# ...

# %% [markdown]
# #### Nota: Vemos que el registro 37 posee caracteres (corresponde al titulo del segundo set de datos). Eliminamos entonces dicho registro del dataframe:

# %%
if 37 in ds_talla.index:
    ds_talla = ds_talla.drop(37)
ds_talla
# Out:
#    Sex Agemos             L            M            S           P3  \
# 0    1      0   1.267004226  49.98888408  0.053112191   44.9250978
# 1    1    0.5   0.511237696   52.6959753  0.048692684  47.97812373
# 2    1    1.5   -0.45224446  56.62842855   0.04411683  52.19859469
# 3    1    2.5  -0.990594599  59.60895343  0.041795583   55.2632178
# 4    1    3.5  -1.285837689  62.07700027  0.040454126  57.73049293
# 5    1    4.5   -1.43031238   64.2168641  0.039633879  59.82568616
# 6    1    5.5   -1.47657547   66.1253149  0.039123813  61.66383709
# 7    1    6.5  -1.456837849   67.8601799  0.038811994  63.31224239
# 8    1    7.5  -1.391898768  69.45908458  0.038633209   64.8139542
# 9    1    8.5   -1.29571459  70.94803912  0.038546833   66.1983257
# 10   1    9.5  -1.177919048  72.34586111  0.038526262  67.48634824
# 11   1   10.5  -1.045326049   73.6666541  0.038553387  68.69360304
# 12   1   11.5  -0.902800887  74.92129717  0.038615501  69.83200143
# ...

# %% [markdown]
# #### Ahora se lo visualiza correcto. Seguimos con la revisión.

# %%
ds_talla.describe()
# Out:
#        Sex Agemos            L            M            S           P3  \
# count   74     74           74           74           74           74
# unique   2     37           74           74           74           74
# top      2   19.5  -1.29571459  93.19854429  0.039123813  55.85939936
# freq    37      2            1            1            1            1
#
#                  P5          P10          P25          P50          P75  \
# count            74           74           74           74           74
# unique           74           74           74           74           74
# top     88.06503203  87.61550158  88.22787587  93.19854429  79.82612621
# freq              1            1            1            1            1
#
#                 P90          P95          P97         Pub3         Pub5  \
# count            74           74           74           74           74
# unique           74           74           74           74           74
# ...

# %%
# Verificamos los tipos de datos de cada campo:
ds_talla.dtypes
# Out:
# Sex       object
# Agemos    object
# L         object
# M         object
# S         object
# P3        object
# P5        object
# P10       object
# P25       object
# P50       object
# P75       object
# P90       object
# P95       object
# P97       object
# Pub3      object
# Pub5      object
# Pub10     object
# Pub25     object
# Pub50     object
# Pub75     object
# Pub90     object
# Pub95     object
# Pub97     object
# Diff3     object
# Diff5     object
# Diff10    object
# Diff25    object
# Diff50    object
# Diff75    object
# Diff90    object
# Diff95    object
# Diff97    object
# dtype: object

# %% [markdown]
# #### Nota: Los datos son numéricos, pero por alguna razón la importación los ha detectado como objetos (string). Los convertiremos al formato correcto por columna para poder realizar operaciones con ellos luego:

# %%
for column in ds_talla.columns.tolist():
    ds_talla[column] = pandas.to_numeric(ds_talla[column])
ds_talla.dtypes
# Out:
# Sex         int64
# Agemos    float64
# L         float64
# M         float64
# S         float64
# P3        float64
# P5        float64
# P10       float64
# P25       float64
# P50       float64
# P75       float64
# P90       float64
# P95       float64
# P97       float64
# Pub3      float64
# Pub5      float64
# Pub10     float64
# Pub25     float64
# Pub50     float64
# Pub75     float64
# Pub90     float64
# Pub95     float64
# Pub97     float64
# Diff3     float64
# Diff5     float64
# Diff10    float64
# Diff25    float64
# Diff50      int64
# Diff75    float64
# Diff90    float64
# Diff95    float64
# Diff97    float64
# dtype: object

# %%
ds_talla.describe()
# Out:
#              Sex     Agemos          L          M          S         P3  \
# count  74.000000  74.000000  74.000000  74.000000  74.000000  74.000000
# mean    1.500000  17.513514   0.398686  78.257342   0.040798  72.393538
# std     0.503413  10.727309   0.919320  12.544763   0.002480  11.633842
# min     1.000000   0.000000  -1.476575  49.286396   0.038526  44.925098
# 25%     1.000000   8.500000  -0.195928  69.742223   0.039389  64.929442
# 50%     1.500000  17.500000   0.642304  80.625305   0.040355  74.700273
# 75%     2.000000  26.500000   1.126814  88.710132   0.041098  81.841167
# max     2.000000  35.500000   1.540391  95.446370   0.053112  88.497741
#
#               P5        P10        P25        P50        P75         P90  \
# count  74.000000  74.000000  74.000000  74.000000  74.000000   74.000000
# mean   73.116705  74.236902  76.127482  78.257342  80.420330   82.397558
# std    11.749392  11.926976  12.221799  12.544763  12.860860   13.137970
# ...

# %%
ds_talla
# Out:
#     Sex  Agemos         L          M         S         P3         P5  \
# 0     1     0.0  1.267004  49.988884  0.053112  44.925098  45.568409
# 1     1     0.5  0.511238  52.695975  0.048693  47.978124  48.558092
# 2     1     1.5 -0.452244  56.628429  0.044117  52.198595  52.726107
# 3     1     2.5 -0.990595  59.608953  0.041796  55.263218  55.773451
# 4     1     3.5 -1.285838  62.077000  0.040454  57.730493  58.237443
# 5     1     4.5 -1.430312  64.216864  0.039634  59.825686  60.336469
# 6     1     5.5 -1.476575  66.125315  0.039124  61.663837  62.182608
# 7     1     6.5 -1.456838  67.860180  0.038812  63.312242  63.841661
# 8     1     7.5 -1.391899  69.459085  0.038633  64.813954  65.355838
# 9     1     8.5 -1.295715  70.948039  0.038547  66.198326  66.753980
# 10    1     9.5 -1.177919  72.345861  0.038526  67.486348  68.056746
# 11    1    10.5 -1.045326  73.666654  0.038553  68.693603  69.279492
# 12    1    11.5 -0.902801  74.921297  0.038616  69.832001  70.433974
# ...

# %% [markdown]
# #### Nota: Ahora los datos se visualizan de forma correcta.

# %% [markdown]
# ---

# %% [markdown]
# ### Analizamos los Pesos:

# %%
ds_peso
# Out:
#     Sex  Agemos         L          M         S         P3         P5  \
# 0     1     0.0  1.815151   3.530203  0.152385   2.355451   2.526904
# 1     1     0.5  1.547523   4.003106  0.146025   2.799549   2.964656
# 2     1     1.5  1.068796   4.879525  0.136479   3.614688   3.774849
# 3     1     2.5  0.695974   5.672889  0.129678   4.342341   4.503255
# 4     1     3.5  0.419815   6.391392  0.124717   4.992898   5.157412
# 5     1     4.5  0.219867   7.041836  0.121040   5.575169   5.744752
# 6     1     5.5  0.077506   7.630425  0.118271   6.096775   6.272175
# 7     1     6.5 -0.021908   8.162951  0.116154   6.564430   6.745993
# 8     1     7.5 -0.089441   8.644832  0.114510   6.984123   7.171952
# 9     1     8.5 -0.133409   9.081120  0.113217   7.361236   7.555287
# 10    1     9.5 -0.160095   9.476500  0.112186   7.700624   7.900755
# 11    1    10.5 -0.174297   9.835308  0.111355   8.006677   8.212684
# 12    1    11.5 -0.179719  10.161536  0.110676   8.283365   8.495000
# ...

# %%
ds_peso.dtypes
# Out:
# Sex         int64
# Agemos    float64
# L         float64
# M         float64
# S         float64
# P3        float64
# P5        float64
# P10       float64
# P25       float64
# P50       float64
# P75       float64
# P90       float64
# P95       float64
# P97       float64
# dtype: object

# %%
ds_peso.describe()
# Out:
#              Sex     Agemos          L          M          S         P3  \
# count  76.000000  76.000000  76.000000  76.000000  76.000000  76.000000
# mean    1.500000  18.000000  -0.159380  10.500653   0.113703   8.555646
# std     0.503322  10.994544   0.627920   2.997212   0.009747   2.581549
# min     1.000000   0.000000  -1.016653   3.399186   0.105084   2.355451
# 25%     1.000000   8.500000  -0.562695   8.681272   0.108187   7.040830
# 50%     1.500000  18.000000  -0.188634  11.351482   0.110096   9.344228
# 75%     2.000000  27.500000  -0.018852  12.884560   0.115375  10.576634
# max     2.000000  36.000000   1.815151  14.329944   0.152385  11.759784
#
#               P5        P10        P25        P50        P75        P90  \
# count  76.000000  76.000000  76.000000  76.000000  76.000000  76.000000
# mean    8.774327   9.123940   9.746218  10.500653  11.331908  12.156645
# std     2.619041   2.684415   2.815592   2.997212   3.223077   3.471963
# ...

# %% [markdown]
# Los pesos se los visualizan de forma correcta. Continuamos.

# %% [markdown]
# ---

# %% [markdown]
# # Obtenemos claves únicas:

# %% [markdown]
# De lo revisado, entendemos que la clave unica esta formada por: Sex, Agemo y el percentil. Transformaremos los datos segun esto:

# %% [markdown]
# ## Alturas:

# %%
# Obtenemos solo las columnas que nos interesan: 
columns_to_ignore = ['L', 'M', 'S', 'Diff3', 'Diff5', 'Diff10', 'Diff25', 'Diff50', 'Diff75', 'Diff90', 'Diff95', 'Diff97']
columns_that_matter = [x for x in ds_talla.columns.tolist() if x not in columns_to_ignore ]
columns_that_matter
# Out:
# ['Sex',
#  'Agemos',
#  'P3',
#  'P5',
#  'P10',
#  'P25',
#  'P50',
#  'P75',
#  'P90',
#  'P95',
#  'P97',
#  'Pub3',
#  'Pub5',
#  'Pub10',
#  'Pub25',
#  'Pub50',
#  'Pub75',
#  'Pub90',
#  'Pub95',
#  'Pub97']

# %%
# Transformamos los datos para obtener los valores de los percentiles segun la clave única:
ds_talla_percentiles = pandas.melt(ds_talla[columns_that_matter], id_vars=['Sex','Agemos'], var_name='Percentiles')
ds_talla_percentiles
# Out:
#       Sex  Agemos Percentiles       value
# 0       1     0.0          P3   44.925098
# 1       1     0.5          P3   47.978124
# 2       1     1.5          P3   52.198595
# 3       1     2.5          P3   55.263218
# 4       1     3.5          P3   57.730493
# 5       1     4.5          P3   59.825686
# 6       1     5.5          P3   61.663837
# 7       1     6.5          P3   63.312242
# 8       1     7.5          P3   64.813954
# 9       1     8.5          P3   66.198326
# 10      1     9.5          P3   67.486348
# 11      1    10.5          P3   68.693603
# 12      1    11.5          P3   69.832001
# 13      1    12.5          P3   70.910878
# 14      1    13.5          P3   71.937697
# 15      1    14.5          P3   72.918530
# 16      1    15.5          P3   73.858391
# 17      1    16.5          P3   74.761471
# 18      1    17.5          P3   75.631316
# 19      1    18.5          P3   76.470956
# 20      1    19.5          P3   77.283000
# ...

# %% [markdown]
# Ahora el dataframe de alturas está listo para graficar. Analizamos los pesos:

# %%
# Obtenemos solo las columnas que nos interesan: 
columns_to_ignore = ['L', 'M', 'S']
columns_that_matter = [x for x in ds_peso.columns.tolist() if x not in columns_to_ignore ]
columns_that_matter
# Out:
# ['Sex', 'Agemos', 'P3', 'P5', 'P10', 'P25', 'P50', 'P75', 'P90', 'P95', 'P97']

# %%
# Transformamos los datos para obtener los valores de los percentiles segun la clave única:
ds_peso_percentiles = pandas.melt(ds_peso[columns_that_matter], id_vars=['Sex','Agemos'], var_name='Percentiles')
ds_peso_percentiles
# Out:
#      Sex  Agemos Percentiles      value
# 0      1     0.0          P3   2.355451
# 1      1     0.5          P3   2.799549
# 2      1     1.5          P3   3.614688
# 3      1     2.5          P3   4.342341
# 4      1     3.5          P3   4.992898
# 5      1     4.5          P3   5.575169
# 6      1     5.5          P3   6.096775
# 7      1     6.5          P3   6.564430
# 8      1     7.5          P3   6.984123
# 9      1     8.5          P3   7.361236
# 10     1     9.5          P3   7.700624
# 11     1    10.5          P3   8.006677
# 12     1    11.5          P3   8.283365
# 13     1    12.5          P3   8.534275
# 14     1    13.5          P3   8.762649
# 15     1    14.5          P3   8.971407
# 16     1    15.5          P3   9.163180
# 17     1    16.5          P3   9.340328
# 18     1    17.5          P3   9.504964
# 19     1    18.5          P3   9.658975
# 20     1    19.5          P3   9.804039
# 21     1    20.5          P3   9.941645
# ...

# %% [markdown]
# ## Acerca de la codificación del campo Sex

# %% [markdown]
# Sobre la codificación del campo Sex, obtuvimos de la pagina https://www.cdc.gov/growthcharts/percentile_data_files.htm que los valores son:

# %% [markdown]
# <H2>&#9658; 1 = male<br/>&#9658; 2 = female</H2>

# %% [markdown]
# Estas codificaciónes las utilizaremos luego para filtrar a la hora de mostrar los gráficos por cada sexo.

# %% [markdown]
# # Gráfico de Alturas por Edad en Niños

# %%
plt.close()
fig, ax = plt.subplots(nrows=1, ncols=1)
ax = sns.pointplot(x="Agemos", y="value", hue='Percentiles', data=ds_talla_percentiles[ds_talla_percentiles['Sex']==1], markers=".")
ax.set_title("Boys Lenght")
ax.set_xlabel("Age");
ax.set_ylabel("Length");
ax.set_xticklabels(ax.get_xticklabels());
plt.show()

# %% [markdown]
# # Gráfico de Alturas por Edad en Niñas

# %%
plt.close()
fig, ax = plt.subplots(nrows=1, ncols=1)
ax = sns.pointplot(x="Agemos", y="value", hue='Percentiles', data=ds_talla_percentiles[ds_talla_percentiles['Sex']==2], markers=".")
ax.set_title("Girls Lenght")
ax.set_xlabel("Age");
ax.set_ylabel("Length");
ax.set_xticklabels(ax.get_xticklabels());
plt.show()

# %% [markdown]
# # Gráfico de Peso por Edad en Niños

# %%
plt.close()
fig, ax = plt.subplots(nrows=1, ncols=1)
ax = sns.pointplot(x="Agemos", y="value", hue='Percentiles', data=ds_peso_percentiles[ds_peso_percentiles['Sex']==1], markers=".")
ax.set_title("Boys Weight")
ax.set_xlabel("Age");
ax.set_ylabel("Weight");
ax.set_xticklabels(ax.get_xticklabels());
plt.show()

# %% [markdown]
# # Gráfico de Peso por Edad en Niñas

# %%
plt.close()
fig, ax = plt.subplots(nrows=1, ncols=1)
ax = sns.pointplot(x="Agemos", y="value", hue='Percentiles', data=ds_peso_percentiles[ds_peso_percentiles['Sex']==2], markers=".")
ax.set_title("Girls Weight")
ax.set_xlabel("Age");
ax.set_ylabel("Weight");
ax.set_xticklabels(ax.get_xticklabels());
plt.show()
